# %% [markdown]
# # Task 3 - Video Games Dataset (from Exploratory Data Project)

# %% [markdown]
# ### Jim Crivello

# %% [markdown]
# ### 02/21/23

# %% [markdown]
# ###

# %% [markdown]
# ## Steps 1-4 - Exploratory Data Project

# %% [markdown]
# ### a. Loading the Video Games Dataset (VGD)

# %%
import pandas as pd

# %%
import numpy as np

# %%
vgd = pd.read_csv('c:/csv/vgsales.csv')

# %%
df = pd.read_csv('c:/csv/vgsales.csv', index_col=0)

# %% [markdown]
# ### b. Viewing Some of the Rows in the Video Games Dataset

# %%
pd.set_option('display.precision', 2)  # format for floating-point values

# %%
vgd.head(7)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7     New Super Mario Bros.       DS  2006.0      Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# ...

# %%
vgd.tail(7)
# Out:
#         Rank                                              Name Platform  \
# 16591  16594                               Myst IV: Revelation       PC
# 16592  16595                                          Plushees       DS
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year       Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16591  2004.0   Adventure     Ubisoft      0.01      0.00       0.0
# 16592  2008.0  Simulation   Destineer      0.01      0.00       0.0
# 16593  2002.0    Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0     Shooter  Infogrames      0.01      0.00       0.0
# ...

# %% [markdown]
# ### c. Customizing the Column Names (Headings)

# %%
vgd.columns = ['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']

# %%
vgd.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ###

# %% [markdown]
# ## Steps 5-7 - Exploratory Data Project - Simple Data Analysis with the Video Games Dataset

# %% [markdown]
# ### a. Use the DataFrame describe() function to calculate basic descriptive statistics for all Video Games numeric columns.

# %%
vgd.describe()
# Out:
#            Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# count  16598.00  16327.00  16598.00  16598.00  16598.00     16598.00
# mean    8300.61   2006.41      0.26      0.15      0.08         0.05
# std     4791.85      5.83      0.82      0.51      0.31         0.19
# min        1.00   1980.00      0.00      0.00      0.00         0.00
# 25%     4151.25   2003.00      0.00      0.00      0.00         0.00
# 50%     8300.50   2007.00      0.08      0.02      0.00         0.01
# 75%    12449.75   2010.00      0.24      0.11      0.04         0.04
# max    16600.00   2020.00     41.49     29.02     10.22        10.57
#
#        Global_Sales
# count      16598.00
# mean           0.54
# std            1.56
# min            0.01
# 25%            0.06
# 50%            0.17
# 75%            0.47
# max           82.74

# %% [markdown]
# ###

# %% [markdown]
# ### b. Use the Series method describe() to calculate basic descriptive statistics for all Video Games category/text columns.

# %%
vgd.describe(include=[object])
# Out:
#                                Name Platform   Genre        Publisher
# count                         16598    16598   16598            16540
# unique                        11493       31      12              578
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2163    3316             1351

# %% [markdown]
# ###

# %% [markdown]
# ### c. Use the Series method unique() to get unique category values.

# %%
print(vgd['Platform'].unique())
# Out:
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' '3DS' 'PS4' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'GC' 'WiiU' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']

# %%
print(vgd['Genre'].unique())
# Out:
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']

# %%
print(vgd['Publisher'].unique())
# Out:
# ['Nintendo' 'Microsoft Game Studios' 'Take-Two Interactive'
#  'Sony Computer Entertainment' 'Activision' 'Ubisoft' 'Bethesda Softworks'
#  'Electronic Arts' 'Sega' 'SquareSoft' 'Atari' '505 Games' 'Capcom'
#  'GT Interactive' 'Konami Digital Entertainment'
#  'Sony Computer Entertainment Europe' 'Square Enix' 'LucasArts'
#  'Virgin Interactive' 'Warner Bros. Interactive Entertainment'
#  'Universal Interactive' 'Eidos Interactive' 'RedOctane' 'Vivendi Games'
#  'Enix Corporation' 'Namco Bandai Games' 'Palcom' 'Hasbro Interactive'
#  'THQ' 'Fox Interactive' 'Acclaim Entertainment' 'MTV Games'
#  'Disney Interactive Studios' nan 'Majesco Entertainment' 'Codemasters'
#  'Red Orb' 'Level 5' 'Arena Entertainment' 'Midway Games' 'JVC'
#  'Deep Silver' '989 Studios' 'NCSoft' 'UEP Systems' 'Parker Bros.' 'Maxis'
#  'Imagic' 'Tecmo Koei' 'Valve Software' 'ASCII Entertainment' 'Mindscape'
#  'Infogrames' 'Unknown' 'Square' 'Valve' 'Activision Value' 'Banpresto'
# ...

# %% [markdown]
# ###

# %% [markdown]
# ## Step 8 - Exploratory Data Project - Numerical Value Column Histogram

# %% [markdown]
# ### a. First Enable Matplotlib support in IPython

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ### b. Use the DataFrame's hist() function to create a histogram for each numerical column

# %%
histogram = vgd.hist()

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ## Extra

# %% [markdown]
# ### Filter - Find Action values within Genre column

# %%
df = df[df['Genre'].str.contains('Action')]

# %%
print("df...\n",df)
# Out:
# df...
#                                                      Name Platform    Year  \
# Rank
# 17                                    Grand Theft Auto V      PS3  2013.0
# 18                         Grand Theft Auto: San Andreas      PS2  2004.0
# 24                                    Grand Theft Auto V     X360  2013.0
# 25                           Grand Theft Auto: Vice City      PS2  2002.0
# 39                                  Grand Theft Auto III      PS2  2001.0
# ...                                                  ...      ...     ...
# 16567      Original Frisbee Disc Sports: Ultimate & Golf       DS  2007.0
# 16570  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS  2014.0
# 16585                                    Planet Monsters      GBA  2001.0
# 16586                                     Carmageddon 64      N64  1999.0
# 16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV  2016.0
#
# ...

# %% [markdown]
# ### List a group of items

# %%
vgd.iloc[['1000','2000','3000', '4000', '5000']]
# Out:
#       Rank                                       Name Platform    Year  \
# 1000  1002                 The Urbz: Sims in the City      PS2  2004.0
# 2000  2002                   F-Zero: Maximum Velocity      GBA  2001.0
# 3000  3002  Tourist Trophy: The Real Riding Simulator      PS2  2006.0
# 4000  4002                  Tony Hawk's Underground 2       GC  2004.0
# 5000  5002                           NFL GameDay 2002      PS2  2001.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 1000  Simulation              Electronic Arts      0.52      0.95      0.00
# 2000      Racing                     Nintendo      0.39      0.16      0.37
# 3000      Racing  Sony Computer Entertainment      0.28      0.22      0.11
# 4000      Sports                   Activision      0.38      0.10      0.00
# 5000      Sports  Sony Computer Entertainment      0.19      0.15      0.00
#
#       Other_Sales  Global_Sales
# 1000         0.29          1.76
# ...

# %% [markdown]
# ### Slice of items

# %%
vgd.iloc[0:35]
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %% [markdown]
# ###

# %% [markdown]
# ## Task 5. - Optional Bonus Section

# %% [markdown]
# ### WordCloud

# %%
from pathlib import Path

# %%
text = Path('c:/csv/vgpublish.txt').read_text()

# %%
import imageio.v2 as imageio

# %%
mask_image =imageio.imread('c:/csv/mask_circle.png')

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(colormap='prism', mask=mask_image, background_color='white')

# %%
wordcloud = wordcloud.generate(text)

# %%
wordcloud = wordcloud.to_file('c:/csv/mask_circle.png')
